# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

average = sum(sales) / len(sales)
spike_limit = average * 1.30
for day in range(len(sales)):
    if sales[day] > spike_limit:
        
        print(f"Day {day + 1}: {sales[day]}")
# Out:
# Day 6: 3000
